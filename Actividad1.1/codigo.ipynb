# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
df= pd.read_csv("Datos_limpios_Berlin2.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13984 entries, 0 to 13983
# Data columns (total 54 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    13984 non-null  int64
#  1   id                                            13984 non-null  int64
#  2   scrape_id                                     13984 non-null  int64
#  3   name                                          13984 non-null  object
#  4   description                                   13984 non-null  object
#  5   host_id                                       13984 non-null  int64
#  6   host_name                                     13984 non-null  object
#  7   host_response_time                            13984 non-null  object
#  8   host_is_superhost                             13984 non-null  object
# ...

# %% [markdown]
# Extraer características a partir de aplicar un análisis univariado, a diferentes variables categóricas (10). Mostrar los resultados obtenidos ,mediante gráficas y tablas

# %%
table1= freq_tbl(df["host_response_time"])
table1= table1.drop(['percentage','cumulative_perc'], axis=1)
table1
# Out:
#    host_response_time  frequency
# 0      within an hour       8501
# 1  within a few hours       2811
# 2        within a day       1949
# 3  a few days or more        723

# %%
index1= table1.set_index("host_response_time")
index1
# Out:
#                     frequency
# host_response_time
# within an hour           8501
# within a few hours       2811
# within a day             1949
# a few days or more        723

# %%
index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table2= freq_tbl(df["host_is_superhost"])
table2= table2.drop(['percentage','cumulative_perc'], axis=1)
table2
# Out:
#   host_is_superhost  frequency
# 0                 f      10860
# 1                 t       3124

# %%
index2= table2.set_index("host_is_superhost")
index2
# Out:
#                    frequency
# host_is_superhost
# f                      10860
# t                       3124

# %%
index2["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table3= freq_tbl(df["host_has_profile_pic"])
table3= table3.drop(['percentage','cumulative_perc'], axis=1)
table3
# Out:
#   host_has_profile_pic  frequency
# 0                    t      13629
# 1                    f        355

# %%
index3= table3.set_index("host_has_profile_pic")
index3
# Out:
#                       frequency
# host_has_profile_pic
# t                         13629
# f                           355

# %%
index3["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table4= freq_tbl(df["host_identity_verified"])
table4= table4.drop(['percentage','cumulative_perc'], axis=1)
table4
# Out:
#   host_identity_verified  frequency
# 0                      t      12746
# 1                      f       1238

# %%
index4= table4.set_index("host_identity_verified")
index4
# Out:
#                         frequency
# host_identity_verified
# t                           12746
# f                            1238

# %%
index4["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table5= freq_tbl(df["neighbourhood"])
table5= table5.drop(['percentage','cumulative_perc'], axis=1)
table5
# Out:
#                                   neighbourhood  frequency
# 0                               Berlin, Germany      13902
# 1                           Berlin, Be, Germany         11
# 2        Berlin Charlottenburg, Berlin, Germany          6
# 3                           Berlin, BE, Germany          5
# 4   Schöneiche bei Berlin, Brandenburg, Germany          4
# 5                     Köpenick, Berlin, Germany          4
# 6                       Berlin - Mitte, Germany          4
# 7            Berlin, Kreuzberg, Berlin, Germany          4
# 8                  Berlin, Deutschland, Germany          4
# 9                        Mitte, Berlin, Germany          3
# 10                    Berlin-Bohnsdorf, Germany          2
# 11               Berlin, Mitte, Berlin, Germany          2
# 12                Berlin-Mitte, Berlin, Germany          2
# 13      Berlin- Charlottenburg, Berlin, Germany          2
# 14              Friedrichshain, Berlin, Germany          2
# ...

# %%
Filtro= table5[table5['frequency']>2]
Filtro
# Out:
#                                  neighbourhood  frequency
# 0                              Berlin, Germany      13902
# 1                          Berlin, Be, Germany         11
# 2       Berlin Charlottenburg, Berlin, Germany          6
# 3                          Berlin, BE, Germany          5
# 4  Schöneiche bei Berlin, Brandenburg, Germany          4
# 5                    Köpenick, Berlin, Germany          4
# 6                      Berlin - Mitte, Germany          4
# 7           Berlin, Kreuzberg, Berlin, Germany          4
# 8                 Berlin, Deutschland, Germany          4
# 9                       Mitte, Berlin, Germany          3

# %%
Filtro_index= Filtro.set_index("neighbourhood")
Filtro_index
# Out:
#                                              frequency
# neighbourhood
# Berlin, Germany                                  13902
# Berlin, Be, Germany                                 11
# Berlin Charlottenburg, Berlin, Germany               6
# Berlin, BE, Germany                                  5
# Schöneiche bei Berlin, Brandenburg, Germany          4
# Köpenick, Berlin, Germany                            4
# Berlin - Mitte, Germany                              4
# Berlin, Kreuzberg, Berlin, Germany                   4
# Berlin, Deutschland, Germany                         4
# Mitte, Berlin, Germany                               3

# %%
Filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Vecindario')
plt.xlabel('Vecindario')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
table6= freq_tbl(df["neighbourhood_cleansed"])
table6= table6.drop(['percentage','cumulative_perc'], axis=1)
table6
# Out:
#         neighbourhood_cleansed  frequency
# 0               Alexanderplatz        869
# 1     Frankfurter Allee Süd FK        759
# 2         Tempelhofer Vorstadt        675
# 3              Brunnenstr. Süd        544
# 4                 Reuterstraße        462
# ..                         ...        ...
# 133  Neu-Hohenschönhausen Nord          3
# 134            Hellersdorf-Süd          3
# 135   Neu-Hohenschönhausen Süd          2
# 136               Marzahn-Nord          1
# 137            Hellersdorf-Ost          1
#
# [138 rows x 2 columns]

# %%
Filtro6= table6[table6['frequency']>250]
Filtro6
# Out:
#       neighbourhood_cleansed  frequency
# 0             Alexanderplatz        869
# 1   Frankfurter Allee Süd FK        759
# 2       Tempelhofer Vorstadt        675
# 3            Brunnenstr. Süd        544
# 4               Reuterstraße        462
# 5    Prenzlauer Berg Südwest        398
# 6       südliche Luisenstadt        391
# 7   Neuköllner Mitte/Zentrum        360
# 8                    Rixdorf        330
# 9            Schöneberg-Nord        321
# 10    Frankfurter Allee Nord        312
# 11  Prenzlauer Berg Nordwest        311
# 12       Prenzlauer Berg Süd        310
# 13         Schillerpromenade        278
# 14               Moabit West        270
# 15            Helmholtzplatz        267
# 16            Schöneberg-Süd        254
# 17   Südliche Friedrichstadt        253

# %%
Filtro_index6= Filtro6.set_index("neighbourhood_cleansed")
Filtro_index6
# Out:
#                           frequency
# neighbourhood_cleansed
# Alexanderplatz                  869
# Frankfurter Allee Süd FK        759
# Tempelhofer Vorstadt            675
# Brunnenstr. Süd                 544
# Reuterstraße                    462
# Prenzlauer Berg Südwest         398
# südliche Luisenstadt            391
# Neuköllner Mitte/Zentrum        360
# Rixdorf                         330
# Schöneberg-Nord                 321
# Frankfurter Allee Nord          312
# Prenzlauer Berg Nordwest        311
# Prenzlauer Berg Süd             310
# Schillerpromenade               278
# Moabit West                     270
# Helmholtzplatz                  267
# Schöneberg-Süd                  254
# Südliche Friedrichstadt         253

# %%
Filtro_index6.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Vecindario')
plt.xlabel('Vecindario')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
table7= freq_tbl(df["property_type"])
table7= table7.drop(['percentage','cumulative_perc'], axis=1)
table7
# Out:
#                          property_type  frequency
# 0                   Entire rental unit       7585
# 1          Private room in rental unit       3148
# 2                         Entire condo        761
# 3            Entire serviced apartment        399
# 4                        Room in hotel        340
# 5                Private room in condo        289
# 6                          Entire loft        261
# 7                 Private room in home        197
# 8                          Entire home        183
# 9                    Entire guesthouse         69
# 10              Room in boutique hotel         64
# 11              Private room in hostel         56
# 12   Private room in bed and breakfast         51
# 13                Private room in loft         50
# 14                  Room in aparthotel         42
# 15                Entire vacation home         42
# 16                           Houseboat         39
# 17          Room in serviced apartment         39
# ...

# %%
Filtro7= table7[table7['frequency']>50]
Filtro7
# Out:
#                         property_type  frequency
# 0                  Entire rental unit       7585
# 1         Private room in rental unit       3148
# 2                        Entire condo        761
# 3           Entire serviced apartment        399
# 4                       Room in hotel        340
# 5               Private room in condo        289
# 6                         Entire loft        261
# 7                Private room in home        197
# 8                         Entire home        183
# 9                   Entire guesthouse         69
# 10             Room in boutique hotel         64
# 11             Private room in hostel         56
# 12  Private room in bed and breakfast         51

# %%
Filtro_index7= Filtro7.set_index("property_type")
Filtro_index7
# Out:
#                                    frequency
# property_type
# Entire rental unit                      7585
# Private room in rental unit             3148
# Entire condo                             761
# Entire serviced apartment                399
# Room in hotel                            340
# Private room in condo                    289
# Entire loft                              261
# Private room in home                     197
# Entire home                              183
# Entire guesthouse                         69
# Room in boutique hotel                    64
# Private room in hostel                    56
# Private room in bed and breakfast         51

# %%
Filtro_index7.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Tipo de propiedad')
plt.xlabel('Tipo de propiedad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
table8= freq_tbl(df["room_type"])
table8= table8.drop(['percentage','cumulative_perc'], axis=1)
table8
# Out:
#          room_type  frequency
# 0  Entire home/apt       9515
# 1     Private room       4306
# 2       Hotel room        117
# 3      Shared room         46

# %%
index8=table8.set_index("room_type")
index8
# Out:
#                  frequency
# room_type
# Entire home/apt       9515
# Private room          4306
# Hotel room             117
# Shared room             46

# %%
index8.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Tipo de cuarto')
plt.xlabel('Tipo de cuarto')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
table9= freq_tbl(df["has_availability"])
table9= table9.drop(['percentage','cumulative_perc'], axis=1)
table9
# Out:
#   has_availability  frequency
# 0                t      13128
# 1                f        856

# %%
index9=table9.set_index("has_availability")
index9
# Out:
#                   frequency
# has_availability
# t                     13128
# f                       856

# %%
index9["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table10= freq_tbl(df["instant_bookable"])
table10= table10.drop(['percentage','cumulative_perc'], axis=1)
table10
# Out:
#   instant_bookable  frequency
# 0                f      10074
# 1                t       3910

# %%
index10=table10.set_index("instant_bookable")
index10
# Out:
#                   frequency
# instant_bookable
# f                     10074
# t                      3910

# %%
index10["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# Categorizar las siguientes variables: ” host_response_rate”, “host_acceptance_rate”, “host_total_listings_count”, “accommodates”, “bathrooms_text”, “beds”, “price”, “maximum_nights_avg_ntm”, “availability_365”, “number_of_reviews”, “review_scores_value”, “reviews_per_month” aplicando la regla de Sturges y desplegar en un gráfico las frecuencias de las categorías obtenidas.

# %%
#Price (11)
df["price"]. info()
n=13984 #aplica para todas
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 13984 entries, 0 to 13983
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 13984 non-null  float64
# dtypes: float64(1)
# memory usage: 109.4 KB

# %%
Max=df["price"].max()
Min=df["price"].min()
Limites= [Min, Max]
print(Limites)
# Out:
# [10.0, 219.0]

# %%
ni= 1+3.32*np.log10(n)
print(ni)
# Out:
# 14.763496298763888

# %%
R=Max-Min
R
# Out:
# 209.0

# %%
i=R/ni
i
# Out:
# 14.156538246126635

# %%
intervalos=np.linspace(9, 219.1, 15)
intervalos
# Out:
# array([  9.        ,  24.00714286,  39.01428571,  54.02142857,
#         69.02857143,  84.03571429,  99.04285714, 114.05      ,
#        129.05714286, 144.06428571, 159.07142857, 174.07857143,
#        189.08571429, 204.09285714, 219.1       ])

# %%
categorias= ["Rango1 (9 USD$ a 24 USD$)","Rango2 (24.01 USD$ a 39.01 USD$ )","Rango3 (39.02 USD$ a 54.02 USD$ )","Rango4 (54.03 USD$ a 69.02 USD$)","Rango5 (69.03 USD$ a 84.03 USD$)","Rango6 (84.04 USD$ a 99.04 USD$)","Rango7 (99.05 USD$ a 114.05 USD$)","Rango8 (114.06 USD$ a 129.05 USD$)","Rango9 (129.06 USD$ a 144.06 USD$)","Rango10 (144.07 USD$ a 159.07 USD$)","Rango11 (159.08 USD$ a 174.07 USD$)","Rango12 (174.08 USD$ a 189.08 USD$)","Rango13 (189.08 USD$ a 204.09 USD$)","Rango14 (204.10 USD$ a 219.1 USD$)"]

# %%
df["price"]=pd.cut(x= df["price"], bins=intervalos, labels= categorias )
df["price"]
# Out:
# 0        Rango9 (129.06 USD$ a 144.06 USD$)
# 1        Rango8 (114.06 USD$ a 129.05 USD$)
# 2          Rango6 (84.04 USD$ a 99.04 USD$)
# 3        Rango9 (129.06 USD$ a 144.06 USD$)
# 4        Rango9 (129.06 USD$ a 144.06 USD$)
#                         ...
# 13979    Rango9 (129.06 USD$ a 144.06 USD$)
# 13980      Rango4 (54.03 USD$ a 69.02 USD$)
# 13981    Rango9 (129.06 USD$ a 144.06 USD$)
# 13982    Rango9 (129.06 USD$ a 144.06 USD$)
# 13983      Rango4 (54.03 USD$ a 69.02 USD$)
# Name: price, Length: 13984, dtype: category
# Categories (14, object): ['Rango1 (9 USD$ a 24 USD$)' < 'Rango2 (24.01 USD$ a 39.01 USD$ )' < 'Rango3 (39.02 USD$ a 54.02 USD$ )' < 'Rango4 (54.03 USD$ a 69.02 USD$)' ... 'Rango11 (159.08 USD$ a 174.07 USD$)' < 'Rango12 (174.08 USD$ a 189.08 USD$)' < 'Rango13 (189.08 USD$ a 204.09 USD$)' < 'Rango14 (204.10 USD$ a 219.1 USD$)']

# %%
table11= freq_tbl(df["price"])
table11= table11.drop(['percentage','cumulative_perc'], axis=1)
table11
# Out:
#                                   price  frequency
# 0    Rango9 (129.06 USD$ a 144.06 USD$)       5402
# 1     Rango7 (99.05 USD$ a 114.05 USD$)       1823
# 2      Rango5 (69.03 USD$ a 84.03 USD$)       1198
# 3      Rango6 (84.04 USD$ a 99.04 USD$)       1136
# 4      Rango4 (54.03 USD$ a 69.02 USD$)       1125
# 5     Rango3 (39.02 USD$ a 54.02 USD$ )        781
# 6    Rango8 (114.06 USD$ a 129.05 USD$)        720
# 7   Rango10 (144.07 USD$ a 159.07 USD$)        426
# 8     Rango2 (24.01 USD$ a 39.01 USD$ )        364
# 9   Rango11 (159.08 USD$ a 174.07 USD$)        300
# 10  Rango13 (189.08 USD$ a 204.09 USD$)        250
# 11  Rango12 (174.08 USD$ a 189.08 USD$)        243
# 12   Rango14 (204.10 USD$ a 219.1 USD$)        143
# 13            Rango1 (9 USD$ a 24 USD$)         73

# %%
index11=table11.set_index("price")
index11
# Out:
#                                      frequency
# price
# Rango9 (129.06 USD$ a 144.06 USD$)        5402
# Rango7 (99.05 USD$ a 114.05 USD$)         1823
# Rango5 (69.03 USD$ a 84.03 USD$)          1198
# Rango6 (84.04 USD$ a 99.04 USD$)          1136
# Rango4 (54.03 USD$ a 69.02 USD$)          1125
# Rango3 (39.02 USD$ a 54.02 USD$ )          781
# Rango8 (114.06 USD$ a 129.05 USD$)         720
# Rango10 (144.07 USD$ a 159.07 USD$)        426
# Rango2 (24.01 USD$ a 39.01 USD$ )          364
# Rango11 (159.08 USD$ a 174.07 USD$)        300
# Rango13 (189.08 USD$ a 204.09 USD$)        250
# Rango12 (174.08 USD$ a 189.08 USD$)        243
# Rango14 (204.10 USD$ a 219.1 USD$)         143
# Rango1 (9 USD$ a 24 USD$)                   73

# %%
index11.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('precio')
plt.xlabel('precio')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#review_scores_value (12)
Max=df["review_scores_value"].max()
Min=df["review_scores_value"].min()
Limites= [Min, Max]
print(Limites)
ni= 1+3.32*np.log10(n)
print(ni)
# Out:
# [4.29, 5.0]
# 14.763496298763888

# %%
intervalos2=np.linspace(4.28, 5.01, 15)
intervalos2
# Out:
# array([4.28      , 4.33214286, 4.38428571, 4.43642857, 4.48857143,
#        4.54071429, 4.59285714, 4.645     , 4.69714286, 4.74928571,
#        4.80142857, 4.85357143, 4.90571429, 4.95785714, 5.01      ])

# %%
categorias2= ["Rango1 (4.28 a 4.33)","Rango2 (4.34 a 4.38 )","Rango3 (4.39 a 4.43)","Rango4 (4.44 a 4.48)","Rango5 (4.49 a 4.54)","Rango6 (4.55 a 4.59)","Rango7 (4.60 a 4.64)","Rango8 (4.65 a 4.69)","Rango9 (4.70 a 4.74)","Rango10 (4.75 a 4.80)","Rango11 (4.81 a 4.85)","Rango12 (4.86 a 4.90)","Rango13 (4.91 a 4.95)","Rango14 (4.96 a 5)"]

# %%
df["review_scores_value"]=pd.cut(x= df["review_scores_value"], bins=intervalos2, labels= categorias2 )
df["review_scores_value"]
# Out:
# 0        Rango11 (4.81 a 4.85)
# 1         Rango9 (4.70 a 4.74)
# 2        Rango13 (4.91 a 4.95)
# 3         Rango9 (4.70 a 4.74)
# 4         Rango9 (4.70 a 4.74)
#                  ...
# 13979       Rango14 (4.96 a 5)
# 13980     Rango9 (4.70 a 4.74)
# 13981     Rango9 (4.70 a 4.74)
# 13982     Rango9 (4.70 a 4.74)
# 13983     Rango9 (4.70 a 4.74)
# Name: review_scores_value, Length: 13984, dtype: category
# Categories (14, object): ['Rango1 (4.28 a 4.33)' < 'Rango2 (4.34 a 4.38 )' < 'Rango3 (4.39 a 4.43)' < 'Rango4 (4.44 a 4.48)' ... 'Rango11 (4.81 a 4.85)' < 'Rango12 (4.86 a 4.90)' < 'Rango13 (4.91 a 4.95)' < 'Rango14 (4.96 a 5)']

# %%
table12= freq_tbl(df["review_scores_value"])
table12= table12.drop(['percentage','cumulative_perc'], axis=1)
table12
# Out:
#       review_scores_value  frequency
# 0    Rango9 (4.70 a 4.74)       5191
# 1      Rango14 (4.96 a 5)       2046
# 2   Rango10 (4.75 a 4.80)       1297
# 3    Rango8 (4.65 a 4.69)        865
# 4   Rango11 (4.81 a 4.85)        786
# 5    Rango5 (4.49 a 4.54)        707
# 6   Rango12 (4.86 a 4.90)        701
# 7    Rango7 (4.60 a 4.64)        581
# 8    Rango6 (4.55 a 4.59)        494
# 9   Rango13 (4.91 a 4.95)        372
# 10   Rango3 (4.39 a 4.43)        274
# 11   Rango1 (4.28 a 4.33)        270
# 12   Rango4 (4.44 a 4.48)        252
# 13  Rango2 (4.34 a 4.38 )        148

# %%
index12=table12.set_index("review_scores_value")
index12
# Out:
#                        frequency
# review_scores_value
# Rango9 (4.70 a 4.74)        5191
# Rango14 (4.96 a 5)          2046
# Rango10 (4.75 a 4.80)       1297
# Rango8 (4.65 a 4.69)         865
# Rango11 (4.81 a 4.85)        786
# Rango5 (4.49 a 4.54)         707
# Rango12 (4.86 a 4.90)        701
# Rango7 (4.60 a 4.64)         581
# Rango6 (4.55 a 4.59)         494
# Rango13 (4.91 a 4.95)        372
# Rango3 (4.39 a 4.43)         274
# Rango1 (4.28 a 4.33)         270
# Rango4 (4.44 a 4.48)         252
# Rango2 (4.34 a 4.38 )        148

# %%
index12.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Calificacion de reseñas ')
plt.xlabel('calificacion')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#maximum_nights_avg_ntm (13)
Max=df["maximum_nights_avg_ntm"].max()
Min=df["maximum_nights_avg_ntm"].min()
Limites= [Min, Max]
print(Limites)
ni= 1+3.32*np.log10(n)
print(ni)
# Out:
# [1.0, 1414.0]
# 14.763496298763888

# %%
np.set_printoptions(suppress=True)
intervalos3=np.linspace(0.9, 1414.1, 15)
intervalos3
# Out:
# array([   0.9       ,  101.84285714,  202.78571429,  303.72857143,
#         404.67142857,  505.61428571,  606.55714286,  707.5       ,
#         808.44285714,  909.38571429, 1010.32857143, 1111.27142857,
#        1212.21428571, 1313.15714286, 1414.1       ])

# %%
categorias3= ["Rango1 (0.9 a 101.84)","Rango2 (101.9 a 202.78)","Rango3 (202.79 a 303.72)","Rango4 (303.73 a 404.67)","Rango5 (404.68 a 505.61)","Rango6 (505.62 a 606.61)","Rango7 (606.62 a 707.5)","Rango8 (707.6 a 808.44)","Rango9 (808.45 a 909.38)","Rango10 (909.39 a 1010.32)","Rango11 (1010.33 a 1111.27)","Rango12 (1111.28 a 1212.21)","Rango13 (1212.22 a 1313.15)", "Rango14 (1313.16 a 1414)"]

# %%
df["maximum_nights_avg_ntm"]=pd.cut(x= df["maximum_nights_avg_ntm"], bins=intervalos3, labels= categorias3 )
df["maximum_nights_avg_ntm"]
# Out:
# 0        Rango12 (1111.28 a 1212.21)
# 1           Rango4 (303.73 a 404.67)
# 2        Rango12 (1111.28 a 1212.21)
# 3        Rango12 (1111.28 a 1212.21)
# 4        Rango12 (1111.28 a 1212.21)
#                     ...
# 13979       Rango4 (303.73 a 404.67)
# 13980       Rango4 (303.73 a 404.67)
# 13981       Rango4 (303.73 a 404.67)
# 13982       Rango4 (303.73 a 404.67)
# 13983        Rango2 (101.9 a 202.78)
# Name: maximum_nights_avg_ntm, Length: 13984, dtype: category
# Categories (14, object): ['Rango1 (0.9 a 101.84)' < 'Rango2 (101.9 a 202.78)' < 'Rango3 (202.79 a 303.72)' < 'Rango4 (303.73 a 404.67)' ... 'Rango11 (1010.33 a 1111.27)' < 'Rango12 (1111.28 a 1212.21)' < 'Rango13 (1212.22 a 1313.15)' < 'Rango14 (1313.16 a 1414)']

# %%
table13= freq_tbl(df["maximum_nights_avg_ntm"])
table13= table13.drop(['percentage','cumulative_perc'], axis=1)
table13
# Out:
#          maximum_nights_avg_ntm  frequency
# 0   Rango12 (1111.28 a 1212.21)       6423
# 1      Rango4 (303.73 a 404.67)       2998
# 2         Rango1 (0.9 a 101.84)       2973
# 3       Rango2 (101.9 a 202.78)        645
# 4       Rango8 (707.6 a 808.44)        342
# 5    Rango10 (909.39 a 1010.32)        251
# 6      Rango3 (202.79 a 303.72)         98
# 7      Rango5 (404.68 a 505.61)         70
# 8   Rango11 (1010.33 a 1111.27)         64
# 9      Rango6 (505.62 a 606.61)         54
# 10      Rango7 (606.62 a 707.5)         47
# 11     Rango9 (808.45 a 909.38)         18
# 12     Rango14 (1313.16 a 1414)          1
# 13  Rango13 (1212.22 a 1313.15)          0

# %%
index13=table13.set_index("maximum_nights_avg_ntm")
index13
# Out:
#                              frequency
# maximum_nights_avg_ntm
# Rango12 (1111.28 a 1212.21)       6423
# Rango4 (303.73 a 404.67)          2998
# Rango1 (0.9 a 101.84)             2973
# Rango2 (101.9 a 202.78)            645
# Rango8 (707.6 a 808.44)            342
# Rango10 (909.39 a 1010.32)         251
# Rango3 (202.79 a 303.72)            98
# Rango5 (404.68 a 505.61)            70
# Rango11 (1010.33 a 1111.27)         64
# Rango6 (505.62 a 606.61)            54
# Rango7 (606.62 a 707.5)             47
# Rango9 (808.45 a 909.38)            18
# Rango14 (1313.16 a 1414)             1
# Rango13 (1212.22 a 1313.15)          0

# %%
index13.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Maximo de noches')
plt.xlabel('Maximo de noches por propiedad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#number_of_review (14)
Max=df["number_of_reviews"].max()
Min=df["number_of_reviews"].min()
Limites= [Min, Max]
print(Limites)
ni= 1+3.32*np.log10(n)
print(ni)
# Out:
# [0.0, 86.0]
# 14.763496298763888

# %%
intervalos4=np.linspace(-1, 86.1, 15)
intervalos4
# Out:
# array([-1.        ,  5.22142857, 11.44285714, 17.66428571, 23.88571429,
#        30.10714286, 36.32857143, 42.55      , 48.77142857, 54.99285714,
#        61.21428571, 67.43571429, 73.65714286, 79.87857143, 86.1       ])

# %%
categorias4= ["Rango1 (0 a 5.22)","Rango2 (5.23 a 11.44)","Rango3 (11.45 a 17.66)","Rango4 (17.67 a 23.88)","Rango5 (23.89 a 30.10)","Rango6 (30.11 a 36.32)","Rango7 (36.33 a 42.55)","Rango8 (42.56 a 48.77)","Rango9 (48.78 a 54.99)","Rango10 (55 a 61.21)","Rango11 (61.22 a 67.43)","Rango12 (67.44 a 73.65)","Rango13 (73.66 a 79.87)","Rango14 (79.88 a 86)"]

# %%
df["number_of_reviews"]=pd.cut(x= df["number_of_reviews"], bins=intervalos4, labels= categorias4 )
df["number_of_reviews"]
# Out:
# 0         Rango2 (5.23 a 11.44)
# 1             Rango1 (0 a 5.22)
# 2        Rango6 (30.11 a 36.32)
# 3             Rango1 (0 a 5.22)
# 4             Rango1 (0 a 5.22)
#                   ...
# 13979     Rango2 (5.23 a 11.44)
# 13980         Rango1 (0 a 5.22)
# 13981         Rango1 (0 a 5.22)
# 13982         Rango1 (0 a 5.22)
# 13983         Rango1 (0 a 5.22)
# Name: number_of_reviews, Length: 13984, dtype: category
# Categories (14, object): ['Rango1 (0 a 5.22)' < 'Rango2 (5.23 a 11.44)' < 'Rango3 (11.45 a 17.66)' < 'Rango4 (17.67 a 23.88)' ... 'Rango11 (61.22 a 67.43)' < 'Rango12 (67.44 a 73.65)' < 'Rango13 (73.66 a 79.87)' < 'Rango14 (79.88 a 86)']

# %%
table14= freq_tbl(df["number_of_reviews"])
table14= table14.drop(['percentage','cumulative_perc'], axis=1)
table14
# Out:
#           number_of_reviews  frequency
# 0         Rango1 (0 a 5.22)       6420
# 1    Rango3 (11.45 a 17.66)       2845
# 2     Rango2 (5.23 a 11.44)       1568
# 3    Rango4 (17.67 a 23.88)        661
# 4    Rango5 (23.89 a 30.10)        539
# 5    Rango6 (30.11 a 36.32)        395
# 6    Rango7 (36.33 a 42.55)        320
# 7    Rango8 (42.56 a 48.77)        245
# 8    Rango9 (48.78 a 54.99)        223
# 9      Rango10 (55 a 61.21)        216
# 10  Rango12 (67.44 a 73.65)        143
# 11     Rango14 (79.88 a 86)        143
# 12  Rango11 (61.22 a 67.43)        140
# 13  Rango13 (73.66 a 79.87)        126

# %%
index14=table14.set_index("number_of_reviews")
index14
# Out:
#                          frequency
# number_of_reviews
# Rango1 (0 a 5.22)             6420
# Rango3 (11.45 a 17.66)        2845
# Rango2 (5.23 a 11.44)         1568
# Rango4 (17.67 a 23.88)         661
# Rango5 (23.89 a 30.10)         539
# Rango6 (30.11 a 36.32)         395
# Rango7 (36.33 a 42.55)         320
# Rango8 (42.56 a 48.77)         245
# Rango9 (48.78 a 54.99)         223
# Rango10 (55 a 61.21)           216
# Rango12 (67.44 a 73.65)        143
# Rango14 (79.88 a 86)           143
# Rango11 (61.22 a 67.43)        140
# Rango13 (73.66 a 79.87)        126

# %%
index14.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Total de reseñas')
plt.xlabel('Reseñas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#reviews_per_month (15)
Max=df["reviews_per_month"].max()
Min=df["reviews_per_month"].min()
Limites= [Min, Max]
print(Limites)
ni= 1+3.32*np.log10(n)
print(ni)
# Out:
# [0.01, 7.17]
# 14.763496298763888

# %%
intervalos5=np.linspace(0.001, 7.18, 15)
intervalos5
# Out:
# array([0.001     , 0.51378571, 1.02657143, 1.53935714, 2.05214286,
#        2.56492857, 3.07771429, 3.5905    , 4.10328571, 4.61607143,
#        5.12885714, 5.64164286, 6.15442857, 6.66721429, 7.18      ])

# %%
categorias5= ["Rango1 (0 a 0.51)","Rango2 (0.52 a 1.02)","Rango3 (1.03 a 1.53)","Rango4 (1.54 a 2.05)","Rango5 (2.06 a 2.56)","Rango6 (2.57 a 3.07)","Rango7 (3.08 a 3.59)","Rango8 (3.6 a 4.10)","Rango9 (4.11 a 4.61)","Rango10 (4.62 a 5.12)","Rango11 (5.13 a 5.64)","Rango12 (5.65 a 6.15)","Rango13 (6.16 a 6.67)","Rango14 (6.66 a 7.18)"]

# %%
df["reviews_per_month"]=pd.cut(x= df["reviews_per_month"], bins=intervalos5, labels= categorias5 )
df["reviews_per_month"]
# Out:
# 0           Rango1 (0 a 0.51)
# 1        Rango6 (2.57 a 3.07)
# 2        Rango4 (1.54 a 2.05)
# 3           Rango1 (0 a 0.51)
# 4        Rango6 (2.57 a 3.07)
#                  ...
# 13979    Rango2 (0.52 a 1.02)
# 13980    Rango6 (2.57 a 3.07)
# 13981    Rango6 (2.57 a 3.07)
# 13982    Rango6 (2.57 a 3.07)
# 13983    Rango6 (2.57 a 3.07)
# Name: reviews_per_month, Length: 13984, dtype: category
# Categories (14, object): ['Rango1 (0 a 0.51)' < 'Rango2 (0.52 a 1.02)' < 'Rango3 (1.03 a 1.53)' < 'Rango4 (1.54 a 2.05)' ... 'Rango11 (5.13 a 5.64)' < 'Rango12 (5.65 a 6.15)' < 'Rango13 (6.16 a 6.67)' < 'Rango14 (6.66 a 7.18)']

# %%
table15= freq_tbl(df["reviews_per_month"])
table15= table15.drop(['percentage','cumulative_perc'], axis=1)
table15
# Out:
#         reviews_per_month  frequency
# 0       Rango1 (0 a 0.51)       5257
# 1    Rango6 (2.57 a 3.07)       3685
# 2    Rango2 (0.52 a 1.02)       1558
# 3    Rango3 (1.03 a 1.53)        955
# 4    Rango4 (1.54 a 2.05)        805
# 5    Rango5 (2.06 a 2.56)        514
# 6    Rango7 (3.08 a 3.59)        374
# 7     Rango8 (3.6 a 4.10)        274
# 8    Rango9 (4.11 a 4.61)        192
# 9   Rango10 (4.62 a 5.12)        135
# 10  Rango11 (5.13 a 5.64)        104
# 11  Rango12 (5.65 a 6.15)         63
# 12  Rango13 (6.16 a 6.67)         42
# 13  Rango14 (6.66 a 7.18)         26

# %%
index15=table15.set_index("reviews_per_month")
index15
# Out:
#                        frequency
# reviews_per_month
# Rango1 (0 a 0.51)           5257
# Rango6 (2.57 a 3.07)        3685
# Rango2 (0.52 a 1.02)        1558
# Rango3 (1.03 a 1.53)         955
# Rango4 (1.54 a 2.05)         805
# Rango5 (2.06 a 2.56)         514
# Rango7 (3.08 a 3.59)         374
# Rango8 (3.6 a 4.10)          274
# Rango9 (4.11 a 4.61)         192
# Rango10 (4.62 a 5.12)        135
# Rango11 (5.13 a 5.64)        104
# Rango12 (5.65 a 6.15)         63
# Rango13 (6.16 a 6.67)         42
# Rango14 (6.66 a 7.18)         26

# %%
index15.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Reseñas por mes')
plt.xlabel('Numero de reseñas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#accommodates (16)
Max=df["accommodates"].max()
Min=df["accommodates"].min()
Limites= [Min, Max]
print(Limites)
ni= 1+3.32*np.log10(n)
print(ni)
# Out:
# [1.0, 7.0]
# 14.763496298763888

# %%
intervalos6=np.linspace(0.1, 7.1, 15)
intervalos6
# Out:
# array([0.1, 0.6, 1.1, 1.6, 2.1, 2.6, 3.1, 3.6, 4.1, 4.6, 5.1, 5.6, 6.1,
#        6.6, 7.1])

# %%
categorias6= ["Rango1 (0.1 a 0.6)","Rango2 (0.7 a 1.1)","Rango3 (1.2 a 1.6)","Rango4 (1.7 a 2.1)","Rango5 (2.2 a 2.6)","Rango6 (2.7 a 3.1)","Rango7 (3.2 a 3.6)","Rango8 (3.7 a 4.1)","Rango9 (4.2 a 4.6)","Rango10 (4.7 a 5.1)","Rango11 (5.2 a 5.6)","Rango12 (5.7 a 6.1)","Rango13 (6.2 a 6.6)","Rango14 (6.7 a 7)"]

# %%
df["accommodates"]=pd.cut(x= df["accommodates"], bins=intervalos6, labels= categorias6 )
df["accommodates"]
# Out:
# 0        Rango4 (1.7 a 2.1)
# 1        Rango4 (1.7 a 2.1)
# 2        Rango4 (1.7 a 2.1)
# 3        Rango4 (1.7 a 2.1)
# 4        Rango6 (2.7 a 3.1)
#                 ...
# 13979    Rango2 (0.7 a 1.1)
# 13980    Rango4 (1.7 a 2.1)
# 13981    Rango4 (1.7 a 2.1)
# 13982    Rango4 (1.7 a 2.1)
# 13983    Rango8 (3.7 a 4.1)
# Name: accommodates, Length: 13984, dtype: category
# Categories (14, object): ['Rango1 (0.1 a 0.6)' < 'Rango2 (0.7 a 1.1)' < 'Rango3 (1.2 a 1.6)' < 'Rango4 (1.7 a 2.1)' ... 'Rango11 (5.2 a 5.6)' < 'Rango12 (5.7 a 6.1)' < 'Rango13 (6.2 a 6.6)' < 'Rango14 (6.7 a 7)']

# %%
table16= freq_tbl(df["accommodates"])
table16= table16.drop(['percentage','cumulative_perc'], axis=1)
table16
# Out:
#            accommodates  frequency
# 0    Rango4 (1.7 a 2.1)       6742
# 1    Rango8 (3.7 a 4.1)       2440
# 2    Rango6 (2.7 a 3.1)       1969
# 3    Rango2 (0.7 a 1.1)       1355
# 4   Rango12 (5.7 a 6.1)        745
# 5   Rango10 (4.7 a 5.1)        582
# 6     Rango14 (6.7 a 7)        151
# 7    Rango1 (0.1 a 0.6)          0
# 8    Rango3 (1.2 a 1.6)          0
# 9    Rango5 (2.2 a 2.6)          0
# 10   Rango7 (3.2 a 3.6)          0
# 11   Rango9 (4.2 a 4.6)          0
# 12  Rango11 (5.2 a 5.6)          0
# 13  Rango13 (6.2 a 6.6)          0

# %%
Filtro16= table16[table16['frequency']>0]
Filtro16
# Out:
#           accommodates  frequency
# 0   Rango4 (1.7 a 2.1)       6742
# 1   Rango8 (3.7 a 4.1)       2440
# 2   Rango6 (2.7 a 3.1)       1969
# 3   Rango2 (0.7 a 1.1)       1355
# 4  Rango12 (5.7 a 6.1)        745
# 5  Rango10 (4.7 a 5.1)        582
# 6    Rango14 (6.7 a 7)        151

# %%
index16=Filtro16.set_index("accommodates")
index16
# Out:
#                      frequency
# accommodates
# Rango4 (1.7 a 2.1)        6742
# Rango8 (3.7 a 4.1)        2440
# Rango6 (2.7 a 3.1)        1969
# Rango2 (0.7 a 1.1)        1355
# Rango12 (5.7 a 6.1)        745
# Rango10 (4.7 a 5.1)        582
# Rango14 (6.7 a 7)          151

# %%
index16.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Inquilinos permitidos por propiedad')
plt.xlabel('Inquilinos')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#availability_365 (17)
Max=df["availability_365"].max()
Min=df["availability_365"].min()
Limites= [Min, Max]
print(Limites)
ni= 1+3.32*np.log10(n)
print(ni)
# Out:
# [0, 365]
# 14.763496298763888

# %%
intervalos7=np.linspace(0.1, 366, 15)
intervalos7
# Out:
# array([  0.1       ,  26.23571429,  52.37142857,  78.50714286,
#        104.64285714, 130.77857143, 156.91428571, 183.05      ,
#        209.18571429, 235.32142857, 261.45714286, 287.59285714,
#        313.72857143, 339.86428571, 366.        ])

# %%
categorias7= ["Rango1 (0 a 26)","Rango2 (27 a 52)","Rango3 (53 a 78)","Rango4 (79 a 104)","Rango5 (105 a 130)","Rango6 (131 a 156)","Rango7 (157 a 183)","Rango8 (184 a 209)","Rango9 (210 a 235)","Rango10 (236 a 261)","Rango11 (262 a 287)","Rango12 (288 a 313)","Rango13 (314 a 339)","Rango14 (340 a 365)"]

# %%
df["availability_365"]=pd.cut(x= df["availability_365"], bins=intervalos7, labels= categorias7 )
df["availability_365"]
# Out:
# 0                        NaN
# 1         Rango7 (157 a 183)
# 2        Rango12 (288 a 313)
# 3                        NaN
# 4                        NaN
#                 ...
# 13979       Rango2 (27 a 52)
# 13980    Rango14 (340 a 365)
# 13981    Rango10 (236 a 261)
# 13982    Rango14 (340 a 365)
# 13983    Rango14 (340 a 365)
# Name: availability_365, Length: 13984, dtype: category
# Categories (14, object): ['Rango1 (0 a 26)' < 'Rango2 (27 a 52)' < 'Rango3 (53 a 78)' < 'Rango4 (79 a 104)' ... 'Rango11 (262 a 287)' < 'Rango12 (288 a 313)' < 'Rango13 (314 a 339)' < 'Rango14 (340 a 365)']

# %%
table17= freq_tbl(df["availability_365"])
table17= table17.drop(['percentage','cumulative_perc'], axis=1)
table17
# Out:
#        availability_365  frequency
# 0   Rango14 (340 a 365)       1996
# 1       Rango1 (0 a 26)        923
# 2     Rango4 (79 a 104)        778
# 3   Rango13 (314 a 339)        762
# 4    Rango7 (157 a 183)        747
# 5   Rango11 (262 a 287)        737
# 6      Rango3 (53 a 78)        653
# 7      Rango2 (27 a 52)        570
# 8   Rango10 (236 a 261)        524
# 9   Rango12 (288 a 313)        464
# 10   Rango6 (131 a 156)        429
# 11   Rango5 (105 a 130)        376
# 12   Rango9 (210 a 235)        367
# 13   Rango8 (184 a 209)        256

# %%
index17=table17.set_index("availability_365")
index17
# Out:
#                      frequency
# availability_365
# Rango14 (340 a 365)       1996
# Rango1 (0 a 26)            923
# Rango4 (79 a 104)          778
# Rango13 (314 a 339)        762
# Rango7 (157 a 183)         747
# Rango11 (262 a 287)        737
# Rango3 (53 a 78)           653
# Rango2 (27 a 52)           570
# Rango10 (236 a 261)        524
# Rango12 (288 a 313)        464
# Rango6 (131 a 156)         429
# Rango5 (105 a 130)         376
# Rango9 (210 a 235)         367
# Rango8 (184 a 209)         256

# %%
index17.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Disponibilidad en los proximos 365 días')
plt.xlabel('Dias disponibles')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#beds (18)
Max=df["beds"].max()
Min=df["beds"].min()
Limites= [Min, Max]
print(Limites)
ni= 1+3.32*np.log10(n)
print(ni)
# Out:
# [0.0, 3.0]
# 14.763496298763888

# %%
intervalos8=np.linspace(0.1, 3.1, 15)
intervalos8
# Out:
# array([0.1       , 0.31428571, 0.52857143, 0.74285714, 0.95714286,
#        1.17142857, 1.38571429, 1.6       , 1.81428571, 2.02857143,
#        2.24285714, 2.45714286, 2.67142857, 2.88571429, 3.1       ])

# %%
categorias8= ["Rango1 (0 a 0.3)","Rango2 (0.32 a 0.52)","Rango3 (0.53 a 0.74)","Rango4 (0.74 a 0.95)","Rango5 (0.96 a 1.17)","Rango6 (1.18 a 1.38)","Rango7 (1.39 a 1.6)","Rango8 (1.61 a 1.81)","Rango9 (1.82 a 2.0)","Rango10 (2.03 a 2.24)","Rango11 (2.25 a 2.45)","Rango12 (2.46 a 2.67)","Rango13 (2.68 a 2.88)","Rango14 (2.89 a 3)"]

# %%
df["beds"]=pd.cut(x= df["beds"], bins=intervalos8, labels= categorias8 )
df["beds"]
# Out:
# 0        Rango5 (0.96 a 1.17)
# 1        Rango5 (0.96 a 1.17)
# 2        Rango5 (0.96 a 1.17)
# 3        Rango5 (0.96 a 1.17)
# 4        Rango5 (0.96 a 1.17)
#                  ...
# 13979    Rango5 (0.96 a 1.17)
# 13980    Rango5 (0.96 a 1.17)
# 13981    Rango5 (0.96 a 1.17)
# 13982    Rango5 (0.96 a 1.17)
# 13983    Rango5 (0.96 a 1.17)
# Name: beds, Length: 13984, dtype: category
# Categories (14, object): ['Rango1 (0 a 0.3)' < 'Rango2 (0.32 a 0.52)' < 'Rango3 (0.53 a 0.74)' < 'Rango4 (0.74 a 0.95)' ... 'Rango11 (2.25 a 2.45)' < 'Rango12 (2.46 a 2.67)' < 'Rango13 (2.68 a 2.88)' < 'Rango14 (2.89 a 3)']

# %%
table18= freq_tbl(df["beds"])
table18= table18.drop(['percentage','cumulative_perc'], axis=1)
table18
# Out:
#                      beds  frequency
# 0    Rango5 (0.96 a 1.17)       9408
# 1     Rango9 (1.82 a 2.0)       2322
# 2    Rango6 (1.18 a 1.38)       1102
# 3      Rango14 (2.89 a 3)        934
# 4        Rango1 (0 a 0.3)          0
# 5    Rango2 (0.32 a 0.52)          0
# 6    Rango3 (0.53 a 0.74)          0
# 7    Rango4 (0.74 a 0.95)          0
# 8     Rango7 (1.39 a 1.6)          0
# 9    Rango8 (1.61 a 1.81)          0
# 10  Rango10 (2.03 a 2.24)          0
# 11  Rango11 (2.25 a 2.45)          0
# 12  Rango12 (2.46 a 2.67)          0
# 13  Rango13 (2.68 a 2.88)          0

# %%
Filtro18= table18[table18['frequency']>0]
Filtro18
# Out:
#                    beds  frequency
# 0  Rango5 (0.96 a 1.17)       9408
# 1   Rango9 (1.82 a 2.0)       2322
# 2  Rango6 (1.18 a 1.38)       1102
# 3    Rango14 (2.89 a 3)        934

# %%
index18=Filtro18.set_index("beds")
index18
# Out:
#                       frequency
# beds
# Rango5 (0.96 a 1.17)       9408
# Rango9 (1.82 a 2.0)        2322
# Rango6 (1.18 a 1.38)       1102
# Rango14 (2.89 a 3)          934

# %%
index18.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('camas por propiedad')
plt.xlabel('Numero de camas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#review_scores_location   (19)
Max=df["review_scores_location"].max() 
Min=df["review_scores_location"].min()
Limites= [Min, Max]
print(Limites)
ni= 1+3.32*np.log10(n)
print(ni)
# Out:
# [4.47, 5.0]
# 14.763496298763888

# %%
intervalos9=np.linspace(4.46, 5.01, 15)
intervalos9
# Out:
# array([4.46      , 4.49928571, 4.53857143, 4.57785714, 4.61714286,
#        4.65642857, 4.69571429, 4.735     , 4.77428571, 4.81357143,
#        4.85285714, 4.89214286, 4.93142857, 4.97071429, 5.01      ])

# %%
categorias9= ["Rango1 (4.46 a 4.49)","Rango2 (4.50 a 4.53)","Rango3 (4.53 a 4.57)","Rango4 (4.58 a 4.61)","Rango5 (4.62 a 4.65)","Rango6 (4.66 a 4.69)","Rango7 (4.70 a 4.735)","Rango8 (4.736 a 4.77)","Rango9 (4.78 a 4.81)","Rango10 (4.82 a 4.85)","Rango11 (4.86 a 4.89)","Rango12 (4.9 a 4.93)","Rango13 (4.93 a 4.97)","Rango14 (4.98 a 5)"]

# %%
df["review_scores_location"]=pd.cut(x= df["review_scores_location"], bins=intervalos9, labels= categorias9 )
df["review_scores_location"]
# Out:
# 0         Rango5 (4.62 a 4.65)
# 1         Rango9 (4.78 a 4.81)
# 2        Rango13 (4.93 a 4.97)
# 3         Rango9 (4.78 a 4.81)
# 4         Rango9 (4.78 a 4.81)
#                  ...
# 13979     Rango9 (4.78 a 4.81)
# 13980     Rango9 (4.78 a 4.81)
# 13981     Rango9 (4.78 a 4.81)
# 13982     Rango9 (4.78 a 4.81)
# 13983     Rango9 (4.78 a 4.81)
# Name: review_scores_location, Length: 13984, dtype: category
# Categories (14, object): ['Rango1 (4.46 a 4.49)' < 'Rango2 (4.50 a 4.53)' < 'Rango3 (4.53 a 4.57)' < 'Rango4 (4.58 a 4.61)' ... 'Rango11 (4.86 a 4.89)' < 'Rango12 (4.9 a 4.93)' < 'Rango13 (4.93 a 4.97)' < 'Rango14 (4.98 a 5)']

# %%
table19= freq_tbl(df["review_scores_location"])
table19= table19.drop(['percentage','cumulative_perc'], axis=1)
table19
# Out:
#    review_scores_location  frequency
# 0    Rango9 (4.78 a 4.81)       5113
# 1      Rango14 (4.98 a 5)       2898
# 2    Rango12 (4.9 a 4.93)        850
# 3   Rango11 (4.86 a 4.89)        845
# 4   Rango10 (4.82 a 4.85)        776
# 5   Rango8 (4.736 a 4.77)        632
# 6   Rango13 (4.93 a 4.97)        623
# 7    Rango6 (4.66 a 4.69)        531
# 8   Rango7 (4.70 a 4.735)        449
# 9    Rango2 (4.50 a 4.53)        403
# 10   Rango4 (4.58 a 4.61)        285
# 11   Rango5 (4.62 a 4.65)        283
# 12   Rango3 (4.53 a 4.57)        222
# 13   Rango1 (4.46 a 4.49)         74

# %%
index19=table19.set_index("review_scores_location")
index19
# Out:
#                         frequency
# review_scores_location
# Rango9 (4.78 a 4.81)         5113
# Rango14 (4.98 a 5)           2898
# Rango12 (4.9 a 4.93)          850
# Rango11 (4.86 a 4.89)         845
# Rango10 (4.82 a 4.85)         776
# Rango8 (4.736 a 4.77)         632
# Rango13 (4.93 a 4.97)         623
# Rango6 (4.66 a 4.69)          531
# Rango7 (4.70 a 4.735)         449
# Rango2 (4.50 a 4.53)          403
# Rango4 (4.58 a 4.61)          285
# Rango5 (4.62 a 4.65)          283
# Rango3 (4.53 a 4.57)          222
# Rango1 (4.46 a 4.49)           74

# %%
index19.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Calificacion de ubicacion')
plt.xlabel('Califcacion')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#calculated_host_listings_count (20)
Max=df["calculated_host_listings_count"].max()
Min=df["calculated_host_listings_count"].min()
Limites= [Min, Max]
print(Limites)
ni= 1+3.32*np.log10(n)
print(ni)
# Out:
# [1.0, 6.0]
# 14.763496298763888

# %%
intervalos10=np.linspace(0.9, 6.01, 15)
intervalos10
# Out:
# array([0.9  , 1.265, 1.63 , 1.995, 2.36 , 2.725, 3.09 , 3.455, 3.82 ,
#        4.185, 4.55 , 4.915, 5.28 , 5.645, 6.01 ])

# %%
categorias10= ["Rango1 (1 a 1.25)","Rango2 (1.26 a 1.63)","Rango3 (1.64 a 1.99)","Rango4 (2 a 2.36)","Rango5 (2.37 a 2.72)","Rango6 (2.73 a 3.09)","Rango7 (3.1 a 3.45)","Rango8 (3.46 a 3.82)","Rango9 (3.83 a 4.18)","Rango10 (4.19 a 4.55)","Rango11 (4.56 a 4.91)","Rango12 (4.92 a 5.28)","Rango13 (5.29 a 5.64)","Rango14 (5.65 a 6)"]

# %%
df["calculated_host_listings_count"]=pd.cut(x= df["calculated_host_listings_count"], bins=intervalos10, labels= categorias10 )
df["calculated_host_listings_count"]
# Out:
# 0           Rango1 (1 a 1.25)
# 1        Rango6 (2.73 a 3.09)
# 2           Rango1 (1 a 1.25)
# 3           Rango1 (1 a 1.25)
# 4           Rango1 (1 a 1.25)
#                  ...
# 13979    Rango6 (2.73 a 3.09)
# 13980    Rango2 (1.26 a 1.63)
# 13981      Rango14 (5.65 a 6)
# 13982       Rango4 (2 a 2.36)
# 13983       Rango1 (1 a 1.25)
# Name: calculated_host_listings_count, Length: 13984, dtype: category
# Categories (14, object): ['Rango1 (1 a 1.25)' < 'Rango2 (1.26 a 1.63)' < 'Rango3 (1.64 a 1.99)' < 'Rango4 (2 a 2.36)' ... 'Rango11 (4.56 a 4.91)' < 'Rango12 (4.92 a 5.28)' < 'Rango13 (5.29 a 5.64)' < 'Rango14 (5.65 a 6)']

# %%
table20= freq_tbl(df["calculated_host_listings_count"])
table20= table20.drop(['percentage','cumulative_perc'], axis=1)
table20
# Out:
#    calculated_host_listings_count  frequency
# 0               Rango1 (1 a 1.25)       8436
# 1            Rango2 (1.26 a 1.63)       2398
# 2               Rango4 (2 a 2.36)       1468
# 3            Rango6 (2.73 a 3.09)        651
# 4           Rango12 (4.92 a 5.28)        395
# 5            Rango9 (3.83 a 4.18)        384
# 6              Rango14 (5.65 a 6)        252
# 7            Rango3 (1.64 a 1.99)          0
# 8            Rango5 (2.37 a 2.72)          0
# 9             Rango7 (3.1 a 3.45)          0
# 10           Rango8 (3.46 a 3.82)          0
# 11          Rango10 (4.19 a 4.55)          0
# 12          Rango11 (4.56 a 4.91)          0
# 13          Rango13 (5.29 a 5.64)          0

# %%
Filtro20= table20[table20['frequency']>0]
Filtro20
# Out:
#   calculated_host_listings_count  frequency
# 0              Rango1 (1 a 1.25)       8436
# 1           Rango2 (1.26 a 1.63)       2398
# 2              Rango4 (2 a 2.36)       1468
# 3           Rango6 (2.73 a 3.09)        651
# 4          Rango12 (4.92 a 5.28)        395
# 5           Rango9 (3.83 a 4.18)        384
# 6             Rango14 (5.65 a 6)        252

# %%
index20=Filtro20.set_index("calculated_host_listings_count")
index20
# Out:
#                                 frequency
# calculated_host_listings_count
# Rango1 (1 a 1.25)                    8436
# Rango2 (1.26 a 1.63)                 2398
# Rango4 (2 a 2.36)                    1468
# Rango6 (2.73 a 3.09)                  651
# Rango12 (4.92 a 5.28)                 395
# Rango9 (3.83 a 4.18)                  384
# Rango14 (5.65 a 6)                    252

# %%
index20.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Propiedades del host')
plt.xlabel('numero de propiedades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
